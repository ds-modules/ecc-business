# %%
import pandas as pd
import numpy as np

# %%
startups = pd.read_csv('startups.csv')

# %%
startups
# Out:
#         Unnamed: 0       id     category_code     status  founded_at  \
# 0                0      c:1               web  operating  2005-10-17
# 1                1     c:10       games_video   acquired         NaN
# 2                2    c:100       games_video   acquired         NaN
# 3                3  c:10000   network_hosting  operating  2008-07-26
# 4                4  c:10001       games_video  operating  2008-07-26
# ...            ...      ...               ...        ...         ...
# 196493      196494  c:99940         ecommerce  operating  2007-01-01
# 196494      196495   c:9995  public_relations  operating  2007-11-01
# 196495      196496   c:9996        consulting  operating  1959-01-01
# 196496      196497   c:9997            search  operating  2008-07-01
# 196497      196498   c:9998         ecommerce  operating  2007-09-01
#
#         logo_width  logo_height country_code  investment_rounds  \
# 0              401           54          USA                  0
# ...

# %%
s = startups[startups['status']=='operating']
s
# Out:
#         Unnamed: 0       id     category_code     status  founded_at  \
# 0                0      c:1               web  operating  2005-10-17
# 3                3  c:10000   network_hosting  operating  2008-07-26
# 4                4  c:10001       games_video  operating  2008-07-26
# 5                5  c:10002       advertising  operating  2007-06-27
# 6                6  c:10003         cleantech  operating  2008-08-20
# ...            ...      ...               ...        ...         ...
# 196493      196494  c:99940         ecommerce  operating  2007-01-01
# 196494      196495   c:9995  public_relations  operating  2007-11-01
# 196495      196496   c:9996        consulting  operating  1959-01-01
# 196496      196497   c:9997            search  operating  2008-07-01
# 196497      196498   c:9998         ecommerce  operating  2007-09-01
#
#         logo_width  logo_height country_code  investment_rounds  \
# 0              401           54          USA                  0
# ...

# %%
s['category_code'].value_counts()
# Out:
# category_code
# software            16015
# web                 13485
# other               13122
# ecommerce            8603
# games_video          6944
# mobile               6223
# advertising          5665
# consulting           4816
# enterprise           3908
# biotech              3610
# education            2854
# hardware             2585
# public_relations     2536
# search               2055
# network_hosting      2051
# cleantech            1693
# health               1651
# finance              1306
# social               1227
# medical              1098
# security             1006
# legal                1003
# analytics             965
# travel                902
# local                 781
# hospitality           738
# news                  724
# sports                661
# manufacturing         632
# music                 556
# fashion               538
# photo_video           519
# transportation        476
# real_estate           459
# semiconductor         455
# ...
